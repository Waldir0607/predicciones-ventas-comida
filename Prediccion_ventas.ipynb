# %% [markdown]
# <a href="https://colab.research.google.com/github/Waldir0607/predicciones-ventas-comida/blob/main/Prediccion_ventas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df =pd.read_csv('/content/sales_predictions.csv')
df.head(20)
# Out:
#    Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0            FDA15        9.300          Low Fat         0.016047
# 1            DRC01        5.920          Regular         0.019278
# 2            FDN15       17.500          Low Fat         0.016760
# 3            FDX07       19.200          Regular         0.000000
# 4            NCD19        8.930          Low Fat         0.000000
# 5            FDP36       10.395          Regular         0.000000
# 6            FDO10       13.650          Regular         0.012741
# 7            FDP10          NaN          Low Fat         0.127470
# 8            FDH17       16.200          Regular         0.016687
# 9            FDU28       19.200          Regular         0.094450
# 10           FDY07       11.800          Low Fat         0.000000
# 11           FDA03       18.500          Regular         0.045464
# 12           FDX32       15.100          Regular         0.100014
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %% [markdown]
# # Empezamos a limpiar los datos

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
gp1 = df['Outlet_Establishment_Year']== 1985
df_2 = df[gp1]
df_2
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 7              FDP10          NaN          Low Fat         0.127470
# 18             DRI11          NaN          Low Fat         0.034238
# 21             FDW12          NaN          Regular         0.035400
# 23             FDC37          NaN          Low Fat         0.057557
# 29             FDC14          NaN          Regular         0.072222
# ...              ...          ...              ...              ...
# 8485           DRK37          NaN          Low Fat         0.043792
# 8487           DRG13          NaN          Low Fat         0.037006
# 8488           NCN14          NaN          Low Fat         0.091473
# 8490           FDU44          NaN          Regular         0.102296
# 8504           NCN18          NaN          Low Fat         0.124111
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 7               Snack Foods  107.7622            OUT027
# ...

# %%
df.loc[df['Item_Weight'].isnull()]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 7              FDP10          NaN          Low Fat         0.127470
# 18             DRI11          NaN          Low Fat         0.034238
# 21             FDW12          NaN          Regular         0.035400
# 23             FDC37          NaN          Low Fat         0.057557
# 29             FDC14          NaN          Regular         0.072222
# ...              ...          ...              ...              ...
# 8485           DRK37          NaN          Low Fat         0.043792
# 8487           DRG13          NaN          Low Fat         0.037006
# 8488           NCN14          NaN          Low Fat         0.091473
# 8490           FDU44          NaN          Regular         0.102296
# 8504           NCN18          NaN          Low Fat         0.124111
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 7               Snack Foods  107.7622            OUT027
# ...

# %%
df['Item_Weight'] = df['Item_Weight'].interpolate(method='linear')

# %%
df.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df.loc[df['Outlet_Size'].isnull()]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 3              FDX07       19.200          Regular         0.000000
# 8              FDH17       16.200          Regular         0.016687
# 9              FDU28       19.200          Regular         0.094450
# 25             NCD06       13.000          Low Fat         0.099887
# 28             FDE51        5.925          Regular         0.161467
# ...              ...          ...              ...              ...
# 8502           NCH43        8.420          Low Fat         0.070712
# 8508           FDW31       11.350          Regular         0.043246
# 8509           FDG45        8.100          Low Fat         0.214306
# 8514           FDA01       15.000          Regular         0.054489
# 8519           FDS36        8.380          Regular         0.046982
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 3     Fruits and Vegetables  182.0950            OUT010
# ...

# %%
df['Outlet_Size'].fillna('Desconocido', inplace=True)

# %%
df.isna().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year  Outlet_Size Outlet_Location_Type  \
# 0                       1999       Medium               Tier 1
# 1                       2009       Medium               Tier 3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                8523 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                8523 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %% [markdown]
# # Seguimos con la limpieza de los datos mediante visualizaciones que nos ayuden.

# %%
df.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  8523.000000      8523.000000  8523.000000                8523.000000
# mean     12.831222         0.066132   140.992782                1997.831867
# std       4.445074         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       9.000000         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.600000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
colmns_rn = ['Item_Weight','Item_Visibility','Item_MRP','Outlet_Establishment_Year','Item_Outlet_Sales']
fig, ax = plt.subplots(nrows=5, ncols=1, figsize=(8,30))
fig.subplots_adjust(hspace=0.5)
for i, col in enumerate(colmns_rn):
  sns.boxplot(x=col, data=df, ax=ax[i])
  ax[i].set_title(col)

# %%
colmns_r = ['Item_Fat_Content','Item_Type','Outlet_Identifier','Outlet_Size','Outlet_Location_Type','Outlet_Type']
for col in colmns_r:
     print(f'Columna {col}: {df[col].nunique()} subniveles')
# Out:
# Columna Item_Fat_Content: 5 subniveles
# Columna Item_Type: 16 subniveles
# Columna Outlet_Identifier: 10 subniveles
# Columna Outlet_Size: 4 subniveles
# Columna Outlet_Location_Type: 3 subniveles
# Columna Outlet_Type: 4 subniveles

# %%
fig, ax = plt.subplots(nrows=6, ncols=1, figsize=(10,30))
fig.subplots_adjust(hspace=1)
for i, col in enumerate(colmns_r):
  sns.countplot(x=col, data=df, ax=ax[i])
  ax[i].set_title(col)
  ax[i].set_xticklabels(ax[i].get_xticklabels(),rotation=30)
# Out:
# <ipython-input-289-3714929ef8e2>:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[i].set_xticklabels(ax[i].get_xticklabels(),rotation=30)
# <ipython-input-289-3714929ef8e2>:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[i].set_xticklabels(ax[i].get_xticklabels(),rotation=30)
# <ipython-input-289-3714929ef8e2>:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[i].set_xticklabels(ax[i].get_xticklabels(),rotation=30)
# <ipython-input-289-3714929ef8e2>:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[i].set_xticklabels(ax[i].get_xticklabels(),rotation=30)
# <ipython-input-289-3714929ef8e2>:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[i].set_xticklabels(ax[i].get_xticklabels(),rotation=30)
# <ipython-input-289-3714929ef8e2>:6: UserWarning: FixedFormatter should only be used together with FixedLocator
# ...

# %%
for column in df.columns:
  if column in colmns_r:
    df[column] = df[column].str.lower()
fig, ax = plt.subplots(nrows=6, ncols=1, figsize=(10,30))
fig.subplots_adjust(hspace=1)
for i, col in enumerate(colmns_r):
  sns.countplot(x=col, data=df, ax=ax[i])
  ax[i].set_title(col)
  ax[i].set_xticklabels(ax[i].get_xticklabels(),rotation=30)
# Out:
# <ipython-input-290-f75b73ea4769>:9: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[i].set_xticklabels(ax[i].get_xticklabels(),rotation=30)
# <ipython-input-290-f75b73ea4769>:9: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[i].set_xticklabels(ax[i].get_xticklabels(),rotation=30)
# <ipython-input-290-f75b73ea4769>:9: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[i].set_xticklabels(ax[i].get_xticklabels(),rotation=30)
# <ipython-input-290-f75b73ea4769>:9: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[i].set_xticklabels(ax[i].get_xticklabels(),rotation=30)
# <ipython-input-290-f75b73ea4769>:9: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[i].set_xticklabels(ax[i].get_xticklabels(),rotation=30)
# <ipython-input-290-f75b73ea4769>:9: UserWarning: FixedFormatter should only be used together with FixedLocator
# ...

# %%
df['Item_Fat_Content'] = df['Item_Fat_Content'].str.replace('lf', 'low fat', regex=False)
df['Item_Fat_Content'] = df['Item_Fat_Content'].str.replace('reg', 'regular', regex=False)
df['Item_Fat_Content'] = df['Item_Fat_Content'].str.replace('regularular', 'regular', regex=False)
df['Outlet_Type'] = df['Outlet_Type'].str.replace('grocery store', 'supermarket type1', regex=False)

# %%
print(df['Item_Type'].unique())
# Out:
# ['dairy' 'soft drinks' 'meat' 'fruits and vegetables' 'household'
#  'baking goods' 'snack foods' 'frozen foods' 'breakfast'
#  'health and hygiene' 'hard drinks' 'canned' 'breads' 'starchy foods'
#  'others' 'seafood']

# %%
fig, ax = plt.subplots(nrows=6, ncols=1, figsize=(10,30))
fig.subplots_adjust(hspace=1)
for i, col in enumerate(colmns_r):
  sns.countplot(x=col, data=df, ax=ax[i])
  ax[i].set_title(col)
  ax[i].set_xticklabels(ax[i].get_xticklabels(),rotation=30)
# Out:
# <ipython-input-293-3714929ef8e2>:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[i].set_xticklabels(ax[i].get_xticklabels(),rotation=30)
# <ipython-input-293-3714929ef8e2>:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[i].set_xticklabels(ax[i].get_xticklabels(),rotation=30)
# <ipython-input-293-3714929ef8e2>:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[i].set_xticklabels(ax[i].get_xticklabels(),rotation=30)
# <ipython-input-293-3714929ef8e2>:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[i].set_xticklabels(ax[i].get_xticklabels(),rotation=30)
# <ipython-input-293-3714929ef8e2>:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[i].set_xticklabels(ax[i].get_xticklabels(),rotation=30)
# <ipython-input-293-3714929ef8e2>:6: UserWarning: FixedFormatter should only be used together with FixedLocator
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                8523 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                8523 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %% [markdown]
# # Comenzamos con el análisis exploratorio

# %% [markdown]
# Utilizaremos nuestra variable que contiene nuestras columnas categóricas que creamos antes, para así poder explorar estas mediante visualizaciones.

# %%
fig, ax = plt.subplots(nrows=len(colmns_r), ncols=1, figsize=(10,45))
fig.subplots_adjust(hspace=0.5)
for i, col in enumerate(colmns_r):
  sns.countplot(x=col,data=df, ax=ax[i])
  ax[i].set_title(col)
  ax[i].set_xticklabels(ax[i].get_xticklabels(),rotation=30)
# Out:
# <ipython-input-295-816d2cac830a>:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[i].set_xticklabels(ax[i].get_xticklabels(),rotation=30)
# <ipython-input-295-816d2cac830a>:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[i].set_xticklabels(ax[i].get_xticklabels(),rotation=30)
# <ipython-input-295-816d2cac830a>:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[i].set_xticklabels(ax[i].get_xticklabels(),rotation=30)
# <ipython-input-295-816d2cac830a>:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[i].set_xticklabels(ax[i].get_xticklabels(),rotation=30)
# <ipython-input-295-816d2cac830a>:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[i].set_xticklabels(ax[i].get_xticklabels(),rotation=30)
# <ipython-input-295-816d2cac830a>:6: UserWarning: FixedFormatter should only be used together with FixedLocator
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                8523 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                8523 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
df.drop(columns=['Item_Identifier','Item_Visibility','Item_MRP','Outlet_Identifier'], inplace=True)

# %%
df.describe()
# Out:
#        Item_Weight  Outlet_Establishment_Year  Item_Outlet_Sales
# count  8523.000000                8523.000000        8523.000000
# mean     12.831222                1997.831867        2181.288914
# std       4.445074                   8.371760        1706.499616
# min       4.555000                1985.000000          33.290000
# 25%       9.000000                1987.000000         834.247400
# 50%      12.600000                1999.000000        1794.331000
# 75%      16.600000                2004.000000        3101.296400
# max      21.350000                2009.000000       13086.964800

# %%
colm_num = ['Item_Weight','Outlet_Establishment_Year','Item_Outlet_Sales']
fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(15,5))
fig.subplots_adjust(hspace=0.5)
for i, col in enumerate(colm_num):
  if col == 'Item_Weight':
      nbins = 10
  else:
    nbins = 50
  sns.histplot(x=col,data=df, ax=ax[i], bins=nbins, kde = True)
  ax[i].set_title(col)

# %%
df['Item_Outlet_Sales'].describe()
# Out:
# count     8523.000000
# mean      2181.288914
# std       1706.499616
# min         33.290000
# 25%        834.247400
# 50%       1794.331000
# 75%       3101.296400
# max      13086.964800
# Name: Item_Outlet_Sales, dtype: float64

# %% [markdown]
# ***Observaciones:***
# - La mayor parte de los productos tienen un peso que va desde los 7.5 hasta los 16.5.
# - Los años donde se instalaron más puntos de venta fueron entre 1999 y el 2004.
# - Las mayores ventas de artículos en outlet fueron de entre 1794.331 y los 3000.0

# %% [markdown]
# # Visualizaciones para explicar lo requerido en cuanto a ***ayudar a la tienda a comprender las propiedades de los productos y establecimientos que tienen un rol crucial en aumentar las ventas.***

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Weight                8523 non-null   float64
#  1   Item_Fat_Content           8523 non-null   object
#  2   Item_Type                  8523 non-null   object
#  3   Outlet_Establishment_Year  8523 non-null   int64
#  4   Outlet_Size                8523 non-null   object
#  5   Outlet_Location_Type       8523 non-null   object
#  6   Outlet_Type                8523 non-null   object
#  7   Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(2), int64(1), object(5)
# memory usage: 532.8+ KB

# %%
filtro1 = df['Item_Outlet_Sales'] >=1794
filtro2 = df['Outlet_Establishment_Year'] >=1999
df_1 = df[filtro1 & filtro2]

# %%
gp1 = df_1.groupby(['Outlet_Establishment_Year','Outlet_Type'])['Item_Outlet_Sales'].mean()
gp1
# Out:
# Outlet_Establishment_Year  Outlet_Type
# 1999                       supermarket type1    3395.797165
# 2002                       supermarket type1    3276.471884
# 2004                       supermarket type1    3358.484578
# 2007                       supermarket type1    3320.043225
# 2009                       supermarket type2    3162.850785
# Name: Item_Outlet_Sales, dtype: float64

# %%
colores = sns.color_palette('Greens', n_colors=len(gp1))
gp1.plot(kind='bar',color=colores,figsize=(9, 4))
plt.xlabel('Supermercados', fontsize = 15)
plt.xticks(fontsize = 15, rotation = 45)
plt.ylabel('Cantidad vendida', fontsize = 15)
plt.yticks(fontsize = 15)
plt.title('Gráfica del promedio de ventas de establecimientos', fontsize = 15)
plt.grid()
plt.xlim()
plt.ylim()
plt.show()

# %% [markdown]
# # ***Con respecto a los establecimientos que tienen más ventas:***
# En el gráfico se muestra el promedio ***los supermercados que mas ventas tienen junto co su año de apertura***.

# %%
filtro3 = df['Item_Weight'] >= 7.5
df_3 = df[filtro3]

# %%
colores = sns.color_palette('Blues', n_colors=len(gp1))
df_3.groupby(['Item_Fat_Content'])['Item_Type'].size().plot(kind='bar',color=colores)
plt.title('Gráfica de propiedad de productos')
plt.xlabel('Nivel de grasas', fontsize = 15)
plt.ylabel('Cantidad de productos', fontsize = 15)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # ***Con respecto a las propiedades de sus productos:***
# Se puede apreciar que de los productos que mayores ventas tienen, son aquellos que son bajos en grasas.
